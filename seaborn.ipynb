# %%
#Pivot table can be used to perform multiple aggregation

# %%
#pivot table outputs in a multi-dimensional manner and has a way of handling NaN values, we can use the fill_values parameter to
#handle NaN values while groupby functions outputs all the concerned columns as index and the NaN values are just not displayed.

# %%
#Advantage of seaborn includes that many different kinds of plot can be plotted, the number of lines of code will be very less
#and apparently the graphs are aesthetically very beautiful.

# %%
#In seaborn all graphs can be built using figure object as well as axis object...figure object corresponds to the container in
#which graphs are stored and axis object corresponds to each graph.

# %%
#3 types of graph (1)relational (2)distribution and categories....relational includes scatter,lineplot...distribution includes
#histogram,kdeplot and rugplot, categorical includes barplot, countplot,boxplot,violin plot (3)matrix includes heatmap and cluster
#map (4)Regplot (5)multiplot includes jointplot and pairplot

# %% [markdown]
# Seaborn Roadmap
#
# Types of Functions
#
# Figure Level
# Axis Level
#
#
#
# Main Classification
#
# Relational Plot
# Distribution Plot
# Categorical Plot
# Regression Plot
# Matrix Plot
# Multiplots

# %% [markdown]
# Disadvantage of seaborn include that pie-chart cannot be plotted nor can 3d plots be plotted, also to plot subplots u need
# matplotlib

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import plotly.express as px

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#In case of scatterplot the ouput is of a rectangular shape while in case of relplot the output is of a square shape
#relplot is a figure object while scatter plot is a axis object. The advantage with relplot is that a relplot can perform a lot
#of functions. for instance when kind='line' then a lineplot gets plotted, when kind='scatter', then a scatter plot gets plotted
#The advantage with figure level function is that it encompasses a lot of functions within it
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter')

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex',style='time') 
#This graph can help us visualize datapoints based on 2 variables sex and time
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex',style='time',size='size') 
#we can segregate datapoints into 3 categories namely sex time and size
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='sex',style='time',size='size',kind='scatter')

# %%
#now we have to plot a graph between year and lifeexpetancy for india 
import plotly.express as px 

gap=px.data.gapminder()
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
newgp=gap[gap['country']=='India'] 
newgp
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
sns.lineplot(data=newgp,x='year',y='lifeExp')
# Out:
# <AxesSubplot:xlabel='year', ylabel='lifeExp'>

# %%
sns.relplot(data=newgp,x='year',y='lifeExp',kind='line')

# %%
newla=gap[gap['country'].isin(['India','Pakistan','China'])] 
newla.head()
# Out:
#     country continent  year   lifeExp        pop   gdpPercap iso_alpha  \
# 288   China      Asia  1952  44.00000  556263527  400.448611       CHN
# 289   China      Asia  1957  50.54896  637408000  575.987001       CHN
# 290   China      Asia  1962  44.50136  665770000  487.674018       CHN
# 291   China      Asia  1967  58.38112  754550000  612.705693       CHN
# 292   China      Asia  1972  63.11888  862030000  676.900092       CHN
#
#      iso_num
# 288      156
# 289      156
# 290      156
# 291      156
# 292      156

# %%
sns.relplot(kind='line',data=newla,x='year',y='lifeExp',hue='country')

# %%
sns.lineplot(data=newla,x='year',y='lifeExp',hue='country')
# Out:
# <AxesSubplot:xlabel='year', ylabel='lifeExp'>

# %% [markdown]
# One difference that can be also seen between relplot and lineplot is that in case of relplot which is a figure level function
# in case of relplot the elegend lies outside the graph while in case of lineplot, the legend is built within the graph.

# %%
sns.relplot(kind='line',data=newla,x='year',y='lifeExp',hue='country',style='continent')

# %%
newa=gap[gap['country'].isin(['India','Brazil','Germany'])] 
newa.head()
# Out:
#     country continent  year  lifeExp        pop    gdpPercap iso_alpha  \
# 168  Brazil  Americas  1952   50.917   56602560  2108.944355       BRA
# 169  Brazil  Americas  1957   53.285   65551171  2487.365989       BRA
# 170  Brazil  Americas  1962   55.665   76039390  3336.585802       BRA
# 171  Brazil  Americas  1967   57.632   88049823  3429.864357       BRA
# 172  Brazil  Americas  1972   59.504  100840058  4985.711467       BRA
#
#      iso_num
# 168       76
# 169       76
# 170       76
# 171       76
# 172       76

# %%
sns.relplot(kind='line',data=newa,x='year',y='lifeExp',hue='country',style='continent') 
#plots the graphs according to different continents..... america will have different style and so will europe and so will
#asia

# %%
import seaborn as sns 
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#The number of columns made will be equal to number of unique types of smoker and number of rows will be equivalent to number
#of unique kind of sex.

# %%
sns.relplot(kind='line',data=tips,x='total_bill',y='tip',col='smoker',row='sex') 
#we can plot multiple plots using col and row. These are called facet plots and these can be only built in figure level functions
#like relplot not on scatterplot

# %%
import seaborn as sns 
sns.relplot(kind='line',data=gap,x='lifeExp',y='gdpPercap',col='year') 
#As we can see , the graphs can be as many as the number of varieties of year and hence it won't be possible to go through every
#graph, so to make up for that we use a parameter like col_wrap

# %%
import seaborn as sns 
sns.relplot(kind='line',data=gap,x='lifeExp',y='gdpPercap',col='year',col_wrap=3) 
#Now we can see that when col_wrap parameter is used and we use value of 3 then

# %% [markdown]
# This facet plots involving col, row and col_wrap parameters can be built only using figure level functions like relplot and not
# on axis level functions.

# %% [markdown]
# 2. Distribution Plots
#
# 1.used for univariate analysis
# 2.used to find out the distribution
# 3.Range of the observation
# 4.Central Tendency
# 5.is the data bimodal?
# 6.Are there outliers?
#
#
# Plots under distribution plot
#
# 1.histplot
# 2.kdeplot
# 3.rugplot

# %%
#Univariate analysis means that Distribution plots can be used to analyze single columns. 
#Used to find out the distribution of data, used to find out the range of observation. 
#Can be used for finding central tendency for instance mean and median. 
#Can be used to find if the data is bimodal or not meaning if the distribution has 2 peaks then it is bimodal else it is not.
#Can also be found out if the data has got any outliers.

# %%
import seaborn as sns 
import plotly.express as px 
import matplotlib.pyplot as plt

# %%
#Distribution includes some figure level functions and few axes level functions 
#figure level functions include---->dist plot 
#axes level functions include---->histplot, kdeplot and rugplot

# %%
sns.histplot(data=tips,x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(data=tips,x='total_bill',kind='hist')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11064\1203990142.py in <module>
# ----> 1 sns.distplot(data=tips,x='total_bill',kind='hist')
#
# TypeError: distplot() got an unexpected keyword argument 'data'

# %%
sns.displot(data=tips,x='total_bill',kind='hist') 
#displot is a figure level function while histplot is a axes level function

# %%
sns.displot(data=tips,x='total_bill',kind='hist',bins=2)

# %%
sns.displot(data=tips,x='total_bill',kind='hist',bins=4)

# %%
sns.displot(data=tips,x='total_bill',kind='hist',bins=6) 
#we can also increase or decrease the bin size

# %%
sns.displot(data=tips, x='total_bill', kind='hist')

# %%
#It's also possible to visiualize the distribtion of categorical variables using the logic of histogram. Discrete bins are 
#automatically set for categorical variables. 
sns.displot(data=tips,x='day',kind='hist')

# %%
#It's also possible to visualize the distribution of categorical variables using the logic of histogram. Discrete bins are 
#automatically set for categorical variables. It's also possible to visualize the distribution of categorical variables using 
#the logic of histogram. Different bins are automatically set for categorical variables.
sns.displot(data=tips,x='day',kind='hist')

# %%
import seaborn as sns 
sns.displot(kind='hist',data=tips,x='tip',hue='sex')

# %%
sns.displot(kind='hist',data=tips,x='tip',hue='sex')

# %%
import seaborn as sns 
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#plotting a hist plot of the age distribution of different sexes
import seaborn as sns 
sns.displot(kind='hist',data=titanic,x='age',hue='sex')

# %%
sns.displot(kind='hist',data=titanic,x='age',hue='sex',element='step')

# %%
sns.histplot(data=titanic,x='age',hue='sex',element='step')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
#as you can see , histplots like above can be built using both axes level function histplot as well as using figure level 
#function displot.

# %%
sns.displot(data=titanic,x='age',col='sex') 
#the art of making different subplots using col or row or both parameters combined is called facet and facet doesnot work with
#axes level functions.

# %%
#kde plot 
#Rather than using different bins, a kde plot smooths the graph with a gaussian kernel, producing a continuous density estimate.
#Rather than using different bins, a kde plot smooths the graph with a gaussian kernel, producing a continuous density estimate.

# %%
#kde produces a continuous density estimate by plotting a smooth graph with a gaussian kernel, kde producs a continuous density
#estimate by plotting a smooth graph using gaussian kernel

# %%
#In case of kde plot, the y-axis represents the density of probablity in your data. In case of kde plot the y-axis is used to 
#estimate the probablity density of a function. In case of kde plot, the y-axis is used to estimate the probablity density of a 
#function. kde plot is continuous probablity estimation of density of a particular dataset. kde plot is continuous probablity
#estimation of density of a particular dataset. kde plot is continuous probablity estimation of density of a particular dataset.
#kde plot is the continuous probablity estimation of the density of a particular dataset.

# %%
sns.kdeplot(data=tips,x='tip')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(data=tips,x='total_bill')
#This graphs shows that the 16/17 will have the highest density according to the probablity estimaton of the density.
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=tips,x='total_bill',hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
import seaborn as sns 
sns.kdeplot(data=tips,x='total_bill',hue='sex',fill=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
import seaborn as sns 
sns.displot(data=tips,kind='kde',x='total_bill',hue='sex',fill=True)

# %%
import seaborn as sns 
sns.displot(data=tips,kind='kde',x='total_bill',hue='sex',fill=True)
#what we can conclude from the below graph is that there is more proablity of finding more number of men paying the total_bill
#between 10 and 20 than the probablity of finding the number of women paying total_bill between 10 and 20

# %%
#The rugplot is intended to compliment the other plots, it involves drawing ticks along x-axis based on datapoints. 
import seaborn as sns 
sns.displot(data=tips,kind='kde',x='total_bill',hue='sex') 
sns.rugplot(data=tips,x='total_bill')
#As you can see, we are getting to see immense density of ticks along the x-axis where the probablity estimation for density is
#highiest and as the probablity estimation for density decreases, the density of ticks decreases as well
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
#Bivariate histogram 
#A bivariate histogram bins the data within he rectangle that tiles the plot, the color of each rectangle represents the density
#of points present within the rectangular tile.

# %%
sns.displot(data=tips,x='total_bill',y='tip',kind='hist')

# %%
import seaborn as sns 
sns.displot(data=tips,x='total_bill',y='tip',kind='hist')

# %%
#bivariate kde plot
#A bivariate kde plot smooths the (x,y) observation with a with a 2D gaussian.
#A bivariate kde plot smooths the (x,y) observation with a 2D gaussian.

# %%
sns.kdeplot(data=tips,x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(data=tips,x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
import seaborn as sns 
import plotly.express as px 
gap=px.data.gapminder()
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
#heatmap is a axes level function....for instance if we want to view the lifeExp for each country, each year then this is how we
#do it. 
import seaborn as sns 
a1=gap.pivot(index='country',columns='year',values='lifeExp') 
a1.head()
# Out:
# year           1952    1957    1962    1967    1972    1977    1982    1987  \
# country
# Afghanistan  28.801  30.332  31.997  34.020  36.088  38.438  39.854  40.822
# Albania      55.230  59.280  64.820  66.220  67.690  68.930  70.420  72.000
# Algeria      43.077  45.685  48.303  51.407  54.518  58.014  61.368  65.799
# Angola       30.015  31.999  34.000  35.985  37.928  39.483  39.942  39.906
# Argentina    62.485  64.399  65.142  65.634  67.065  68.481  69.942  70.774
#
# year           1992    1997    2002    2007
# country
# Afghanistan  41.674  41.763  42.129  43.828
# Albania      71.581  72.950  75.651  76.423
# Algeria      67.744  69.152  70.994  72.301
# Angola       40.647  40.963  41.003  42.731
# Argentina    71.868  73.275  74.340  75.320

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
a1=gap.pivot(index='country',columns='year',values='lifeExp') 
plt.figure(figsize=(25,25))
sns.heatmap(a1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %%
#color=viridis,summer,autmn,rainy,jet
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
#now we have to find lifeExp for countries in Europe 
import matplotlib.pyplot as plt 
import seaborn as sns
euro=gap[gap['continent']=='Europe']
a2=euro.pivot(index='country',columns='year',values='lifeExp') 
plt.figure(figsize=(15,15)) 
sns.heatmap(a2)
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
euro=gap[gap['continent']=='Europe']
a2=euro.pivot(index='country',columns='year',values='lifeExp') 
plt.figure(figsize=(15,15)) 
sns.heatmap(a2,annot=True)
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
euro=gap[gap['continent']=='Europe']
euro1=euro.pivot(index='country',columns='year',values='lifeExp')
plt.figure(figsize=(15,15)) 
sns.heatmap(euro1,annot=True,linewidth=0.5)
#linewidth=0.5 will lead to a width being created across each block and annot=True will display the value of lifeExp w.r.t each
#unique country and year.
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
euro=gap[gap['continent']=='Europe'] 
euro1=euro.pivot(index='country',columns='year',values='lifeExp') 
plt.figure(figsize=(15,15)) 
sns.heatmap(euro1,annot=True,linewidth=0.5,cmap='summer')
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
euro=gap[gap['continent']=='Europe'] 
euro1=euro.pivot(index='country',columns='year',values='lifeExp') 
plt.figure(figsize=(15,15)) 
sns.heatmap(euro1,annot=True,linewidth=0.5,cmap='viridis')
#cmap is used to color the heatmao in various ways
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
tips=sns.load_dataset('tips') 
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import plotly.express as px
import seaborn as sns 
iris=px.data.iris()
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]]) 
#The similar element will be clustered first and then the next similar elements and further...the columns and rows too have been
#arranged accordingly.

# %%
#ANimation and 3d surface plots cannot be built in seaborn....seaborn,matplolib and plotly is used to build more customizable
#graphs which is not possible using power bi

# %%
#The height and width of figure level functions can be manipulated as shown below 
import plotly.express as px 
import seaborn as sns 

iris=px.data.tips()
iris.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(data=iris,x='total_bill',kind='kde',hue='sex',fill=True,height=10)

# %%
sns.displot(data=iris,x='total_bill',kind='kde',hue='sex',fill=True,height=10,aspect=2)

# %%
#Using the height and aspect parameter, we change the size of figure in case of figure level functions like displot as 
#using plt.figure(figsize=(15,15)) won't work in these cases.

# %%
import seaborn as sns
